# %%
import pandas as pd

df = pd.read_csv('/Users/davidskaff/Downloads/airlineprofit_oilprice__data_final.csv')

print(df.head())
# Out:
#    Year  Crude Oil  American Airlines  Air France  All Nippon Airways  \
# 0  2022      94.53        11014000000   767000000           804201000
# 1  2021      68.17         2046000000 -3895000000          1159749900
# 2  2020      39.68        -5186000000 -8085000000          3113585800
# 3  2019      56.99        13114000000   325000000           407240200
# 4  2018      65.23        10051000000   483000000          1105627300
#
#    Qantas Airways  British Airways  Ethiopian Airlines  Emirates Airlines  \
# 0      -610000000         76860000          6100000000        -1053000000
# 1     -1530000000      -2076480000           937000000        -5454000000
# 2     -1660000000      -4397340000           260000000          270000000
# 3      1050000000       1397340000           122940000          234900000
# 4      1190000000       2635860000           160200000          729000000
#
#    LATAM Airlines  All Airlines
# 0      1339000000   -6900000000
# 1     -4647000000  -42000000000
# ...

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Load your DataFrame
df = pd.read_csv('/Users/davidskaff/Downloads/airlineprofit_oilprice__data_final.csv')

# Convert 'Year' to datetime
df['Year'] = pd.to_datetime(df['Year'], format='%Y')

# Set 'Year' as the index of the dataframe
df.set_index('Year', inplace=True)

# Create a figure and a set of subplots
fig, ax1 = plt.subplots()

# Plot Emirates Airlines profit
color = 'tab:blue'
ax1.set_xlabel('Year')
ax1.set_ylabel('Emirates Airlines Profit (in Billion USD)', color=color)
lns1 = ax1.plot(df.index, df['Emirates Airlines'], color=color, marker='o', label='Emirates Airlines Profit')  # added label
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for crude oil price
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Crude Oil Price (USD per Barrel)', color=color)
lns2 = ax2.plot(df.index, df['Crude Oil'], color=color, marker='o', label='Crude Oil Price')  # added label
ax2.tick_params(axis='y', labelcolor=color)

# Combine legends
lns = lns1 + lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=0)

# Modify x-axis to show every single year
ax1.xaxis.set_major_locator(mdates.YearLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

df = pd.read_csv('/Users/davidskaff/Downloads/airlineprofit_oilprice__data_final.csv')

# Calculate the correlation coefficient
correlation = df['Crude Oil'].corr(df['Emirates Airlines'])
print(f"The correlation coefficient between the crude oil price and the profit of Emirates Airlines is {correlation}")

# Calculate the slope, intercept, and r-squared value for the regression line
slope, intercept, r_value, p_value, std_err = stats.linregress(df['Crude Oil'], df['Emirates Airlines'])

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.regplot(x='Crude Oil', y='Emirates Airlines', data=df)

# Add titles and labels
plt.title('Correlation between Crude Oil Prices and Emirates Airlines Profit')
plt.xlabel('Crude Oil Prices (USD per Barrel)')
plt.ylabel('Emirates Airlines Profit (in Billion USD)')

# Annotate each point with its corresponding year
for i in range(df.shape[0]):
    plt.text(df['Crude Oil'].iloc[i], df['Emirates Airlines'].iloc[i], df['Year'].iloc[i])

# Show the plot
plt.show()

# Print the slope, intercept, and r-squared value below the plot
print(f"Line equation: y = {slope:.2f}x + {intercept:.2f}")
print(f"R-squared value: {r_value**2:.2f}")
# Out:
# The correlation coefficient between the crude oil price and the profit of Emirates Airlines is -0.1528279017463422
# Line equation: y = -13166486.21x + 904939927.08
# R-squared value: 0.02

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Load your DataFrame
df = pd.read_csv('/Users/davidskaff/Downloads/airlineprofit_oilprice__data_final.csv')

# Convert 'Year' to datetime
df['Year'] = pd.to_datetime(df['Year'], format='%Y')

# Set 'Year' as the index of the dataframe
df.set_index('Year', inplace=True)

# Create a figure and a set of subplots
fig, ax1 = plt.subplots()

# Plot LATAM Airlines profit
color = 'tab:blue'
ax1.set_xlabel('Year')
ax1.set_ylabel('LATAM Airlines Profit (in Billion USD)', color=color)
lns1 = ax1.plot(df.index, df['LATAM Airlines'], color=color, marker='o', label='LATAM Airlines Profit')  # added label
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for crude oil price
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Crude Oil Price (USD per Barrel)', color=color)
lns2 = ax2.plot(df.index, df['Crude Oil'], color=color, marker='o', label='Crude Oil Price')  # added label
ax2.tick_params(axis='y', labelcolor=color)

# Combine legends
lns = lns1 + lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=0)

# Modify x-axis to show every single year
ax1.xaxis.set_major_locator(mdates.YearLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

df = pd.read_csv('/Users/davidskaff/Downloads/airlineprofit_oilprice__data_final.csv')

# Calculate the correlation coefficient
correlation = df['Crude Oil'].corr(df['LATAM Airlines'])
print(f"The correlation coefficient between the crude oil price and the profit of LATAM Airlines is {correlation}")

# Calculate the slope, intercept, and r-squared value for the regression line
slope, intercept, r_value, p_value, std_err = stats.linregress(df['Crude Oil'], df['LATAM Airlines'])

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.regplot(x='Crude Oil', y='LATAM Airlines', data=df)

# Add titles and labels
plt.title('Correlation between Crude Oil Prices and LATAM Airlines Profit')
plt.xlabel('Crude Oil Prices (USD per Barrel)')
plt.ylabel('LATAM Airlines Profit (in Billion USD)')

# Annotate each point with its corresponding year
for i in range(df.shape[0]):
    plt.text(df['Crude Oil'].iloc[i], df['LATAM Airlines'].iloc[i], df['Year'].iloc[i])

# Show the plot
plt.show()

# Print the slope, intercept, and r-squared value below the plot
print(f"Line equation: y = {slope:.2f}x + {intercept:.2f}")
print(f"R-squared value: {r_value**2:.2f}")
# Out:
# The correlation coefficient between the crude oil price and the profit of LATAM Airlines is 0.33489869358778956
# Line equation: y = 29135825.26x + -2708378663.59
# R-squared value: 0.11

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Read the data from the CSV file
df = pd.read_csv('/Users/davidskaff/Downloads/airlineprofit_oilprice__data_final.csv')

# List of airlines
airlines = ["Emirates Airlines", "American Airlines", "Air France", "All Nippon Airways", "Qantas Airways", "British Airways", "Ethiopian Airlines", "LATAM Airlines"]

# Create a figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Iterate over each airline
for airline in airlines:
    # Plot the scatter plot with regression line
    sns.regplot(x='Crude Oil', y=airline, data=df, label=f'{airline} (corr={df["Crude Oil"].corr(df[airline]):.2f})', ax=ax)

# Add titles and labels
plt.title('Correlation between Crude Oil Prices and Airlines Profit')
plt.xlabel('Crude Oil Prices (USD per Barrel)')
plt.ylabel('Airlines Profit (in 10 Billion USD)')

# Add a legend outside the graph
plt.legend(loc='lower center', bbox_to_anchor=(0.5, -0.3), ncol=4)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Load your DataFrame
df = pd.read_csv('/Users/davidskaff/Downloads/airlineprofit_oilprice__data_final.csv')

# Convert 'Year' to datetime
df['Year'] = pd.to_datetime(df['Year'], format='%Y')

# Set 'Year' as the index of the dataframe
df.set_index('Year', inplace=True)

# Create a figure and a set of subplots
fig, ax1 = plt.subplots()

# Plot All Airlines profit
color = 'tab:blue'
ax1.set_xlabel('Year')
ax1.set_ylabel('All Airlines Profit (in 100 Billion USD)', color=color)
lns1 = ax1.plot(df.index, df['All Airlines'], color=color, marker='o', label='All Airlines Profit')  # added label
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for crude oil price
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Crude Oil Price (USD per Barrel)', color=color)
lns2 = ax2.plot(df.index, df['Crude Oil'], color=color, marker='o', label='Crude Oil Price')  # added label
ax2.tick_params(axis='y', labelcolor=color)

# Combine legends
lns = lns1 + lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=0)

# Modify x-axis to show every single year
ax1.xaxis.set_major_locator(mdates.YearLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

df = pd.read_csv('/Users/davidskaff/Downloads/airlineprofit_oilprice__data_final.csv')

# Calculate the correlation coefficient
correlation = df['Crude Oil'].corr(df['All Airlines'])
print(f"The correlation coefficient between the crude oil price and the profit of All Airlines is {correlation}")

# Calculate the slope, intercept, and r-squared value for the regression line
slope, intercept, r_value, p_value, std_err = stats.linregress(df['Crude Oil'], df['All Airlines'])

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.regplot(x='Crude Oil', y='All Airlines', data=df)

# Add titles and labels
plt.title('Correlation between Crude Oil Prices and All Airlines Profit')
plt.xlabel('Crude Oil Prices (USD per Barrel)')
plt.ylabel('All Airlines Profit (in 100 Billion USD)')

# Annotate each point with its corresponding year
for i in range(df.shape[0]):
    plt.text(df['Crude Oil'].iloc[i], df['All Airlines'].iloc[i], df['Year'].iloc[i])

# Show the plot
plt.show()

# Print the slope, intercept, and r-squared value below the plot
print(f"Line equation: y = {slope:.2f}x + {intercept:.2f}")
print(f"R-squared value: {r_value**2:.2f}")
# Out:
# The correlation coefficient between the crude oil price and the profit of All Airlines is 0.17679936187165576
# Line equation: y = 401884525.79x + -26712563626.05
# R-squared value: 0.03
