# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
from pathlib import Path
import pandas as pd
import scipy.stats as stats

# %% [markdown]
# # Comparison of Frequency of Exercise and Pain Tolerance

# %% [markdown]
# # Description
#
# Suppose we decided to poll 1,000 people from San Francisco. They had differing amounts of times that they exercised throughout the week. We also wanted to understand what their pain tolerance was on a scale of 1 to 100.
#
# Variable          Values
# num_workouts:       0=zero workouts, 1=one 30 minute workout, 2=two 30 minute workouts, 3=three 30   minute workouts, 4=four or more 30 minute workouts
# pain_tolerance: how much pain a person can tolerate.

# %%
# Create a file path
exercise_data = Path("../Resources/pain_tolerance.csv")

# Read in the data.
exercise_data_df = pd.read_csv(exercise_data)
exercise_data_df.head()
# Out:
#    num_workouts  pain_tolerance
# 0             0             100
# 1             0              71
# 2             0              56
# 3             0              67
# 4             0              92

# %%
# Create a boxplot to compare means
exercise_data_df.boxplot("pain_tolerance", by="num_workouts", figsize=(20, 10))
# Out:
# <AxesSubplot:title={'center':'pain_tolerance'}, xlabel='num_workouts'>

# %%
# Extract individual groups
group0 = exercise_data_df[exercise_data_df["num_workouts"] == 0]["pain_tolerance"]
group1 = exercise_data_df[exercise_data_df["num_workouts"] == 1]["pain_tolerance"]
group2 = exercise_data_df[exercise_data_df["num_workouts"] == 2]["pain_tolerance"]
group3 = exercise_data_df[exercise_data_df["num_workouts"] == 3]["pain_tolerance"]
group4 = exercise_data_df[exercise_data_df["num_workouts"] == 4]["pain_tolerance"]

# %%
# Perform the ANOVA
stats.f_oneway(group0, group1, group2, group3, group4)
# Out:
# F_onewayResult(statistic=23.745245488415385, pvalue=8.871245906612542e-19)
